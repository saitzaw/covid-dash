# %% [markdown]
# <a href="https://colab.research.google.com/github/saitzaw/math4all/blob/master/COVID_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
virus_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/covid19_data.csv')

# %%
date = virus_data['Date']
daily_death = virus_data['daily death']
total_death = virus_data['total death']

# %%
plt.subplot(2,1,1)
plt.rcParams['figure.figsize'] = [20, 5]
time = np.arange(len(daily_death))
ax = plt.gca()
ax.set_xticks(time)
ax.xaxis.set_major_formatter(plt.NullFormatter())
plt.title("daily death in linear")
plt.plot(time, daily_death)
plt.grid()

plt.subplot(2,1,2)
plt.rcParams['figure.figsize'] = [20, 5]
time = np.arange(len(daily_death))
ax = plt.gca()
ax.set_xticks(time)
plt.title("daily death in log")
plt.plot(time, np.log(daily_death))
x_ticks = []
locs, labels = plt.xticks() 
new_xticks = date
plt.xticks(locs,new_xticks,rotation=45, horizontalalignment='right')
plt.grid()

# %%
daily_case = virus_data['daily case']
total_case = virus_data['total case']

# %%
plt.subplot(2,1,1)
plt.rcParams['figure.figsize'] = [18, 5]
time = np.arange(len(daily_case))
ax = plt.gca()
ax.set_xticks(time)
ax.xaxis.set_major_formatter(plt.NullFormatter())
plt.title("daily case in linear")
plt.plot(time, daily_case)
plt.grid()

plt.subplot(2,1,2)
plt.rcParams['figure.figsize'] = [18, 5]
time = np.arange(len(daily_case))
ax = plt.gca()
ax.set_xticks(time)
plt.title("dail case in log")
plt.plot(time, np.log(daily_case))
x_ticks = []
locs, labels = plt.xticks() 
new_xticks = date
plt.xticks(locs,new_xticks,rotation=45, horizontalalignment='right')
plt.grid()

# %%
#bar chart 
plt.rcParams['figure.figsize'] = [18,5]
time = np.arange(len(daily_death))
ax = plt.gca()
ax.set_xticks(time)
ax.xaxis.set_major_formatter(plt.NullFormatter())
plt.title("death toll")
plt.bar(time, daily_death,0.35,label="dail death")
plt.bar(time+0.35, total_death,0.35,label="total death")
x_ticks = []
locs, labels = plt.xticks() 
new_xticks = date
plt.xticks(locs,new_xticks,rotation=45, horizontalalignment='right')
plt.legend()
plt.grid()

# %%
#Description for daily Death Toll 
daily_death.describe()
# Out:
# count     24.000000
# mean      68.833333
# std       42.511039
# min        8.000000
# 25%       35.000000
# 50%       65.000000
# 75%       97.000000
# max      146.000000
# Name: daily death, dtype: float64

# %%
plt.rcParams['figure.figsize'] = [18,5]
daily_death_collection = sns.boxplot(daily_death)

# %%
import scipy.stats as stats
# mu = 62.090909
# sigma = 37.520673
# x = np.linspace(8, 146, 100)
# y = stats.norm.pdf(x, mu,sigma)
# plt.plot(x,y)
# plt.grid()
sns.distplot(daily_death, rug=True)

# %%
#Description for total Death Toll 
total_death.describe()
# Out:
# count      24.000000
# mean      595.333333
# std       508.998989
# min        25.000000
# 25%       160.500000
# 50%       459.000000
# 75%       937.000000
# max      1669.000000
# Name: total death, dtype: float64

# %%
plt.rcParams['figure.figsize'] = [18, 5]
total_death_collection = sns.boxplot(total_death)

# %%
# mu = 504.227273
# sigma = 422.990029
# x = np.linspace(25, 1383, 1000)
# y = stats.norm.pdf(x, mu,sigma)
# plt.plot(x,y)
# plt.grid()
sns.distplot(total_death, rug=True)

# %%
# virus infection 
plt.rcParams['figure.figsize'] = [18,5]
time = np.arange(len(daily_case))
ax = plt.gca()
ax.set_xticks(time)
ax.xaxis.set_major_formatter(plt.NullFormatter())
plt.title("virus infection")
plt.bar(time, daily_case,0.35,label="dail case")
plt.bar(time+0.35, total_case,0.35,label="total case")
x_ticks = []
locs, labels = plt.xticks() 
new_xticks = date
plt.xticks(locs,new_xticks,rotation=45, horizontalalignment='right')
plt.legend()
plt.grid()

# %%
#Descritption of daily infection by COVID-19 
daily_case.describe()
# Out:
# count       24.000000
# mean      2850.333333
# std       2669.521349
# min         56.000000
# 25%       1774.500000
# 50%       2574.500000
# 75%       3182.000000
# max      14113.000000
# Name: daily case, dtype: float64

# %%
plt.rcParams['figure.figsize'] = [18,5]
sns.boxplot(daily_case)

# %%
#Description of total infection by COVID-19 
total_case.describe()
# Out:
# count       24.000000
# mean     26887.333333
# std      22339.650310
# min        844.000000
# 25%       7374.250000
# 50%      22589.500000
# 75%      41189.500000
# max      69197.000000
# Name: total case, dtype: float64

# %%
plt.rcParams['figure.figsize'] = [18,5]
sns.boxplot(total_case)

# %%
sns.distplot(total_case)

# %%
labels = ['death','infection']
daily_sizes = [np.average(daily_death), np.average(daily_case)]
total_sizes = [np.average(total_death), np.average(total_case)]
plt.subplot(1,2,1)
plt.pie(daily_sizes, labels=labels)    
plt.title("comparison for daily death and infection")    
plt.subplot(1,2,2)
plt.pie(total_sizes, labels=labels)    
plt.title("comparison for total death and infection")
# Out:
# Text(0.5, 1.0, 'comparison for total death and infection')

# %%
#recovery 
report_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/covid19_report.csv')
summerize_labels = ['Total COVID-19 Infection Case', 'Total Deaths', 'Total Recovery', 'Active Infected Patient', 'Active Mild Condition', 'Active Critical']
pie_data = [
            report_data['total covid cases'],
            report_data['total deaths'],
            report_data['total recovery'],
            report_data['active infected patient'],
            report_data['active mild condition'],
            report_data['active critical']
            ] 
plt.pie(pie_data, labels=summerize_labels)
plt.title('Summerization')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   # This is added back by InteractiveShellApp.init_path()
# Text(0.5, 1.0, 'Summerization')
